# %%
import pandas as pd
df = pd.read_csv('./data/cs.csv')
df = df.tail(2)
df.to_csv('./data/cs_tail2.csv')
print(df.tail(2))
# Out:
#    姓名 成本中心  早餐  中餐  晚餐
# 3  赵六   车间   6  20  22
# 4  钱7   人事   2  12  12

# %%
# 访问json数据
import json
with open('./data/cs.json', 'r', encoding='utf-8') as f:
    data = json.load(f) 

df = pd.DataFrame(data['usres'])
print(df)
# Out:
#      id name  age
# 0  1001   张三   18
# 1  1002   李四   20
# 2  1003   王五   22
